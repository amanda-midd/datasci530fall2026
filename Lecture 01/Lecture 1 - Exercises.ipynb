# %% [markdown]
# # Lecture 1 Exercises

# %% [markdown]
# ## Short Questions
#
# <font size = "5">
#
# 1. What is the difference between a list and an array?
# 2. Consider the list <br>
#
# ```list_colors = ["red","yellow","green"]``` <br>
#
# What is the output of ```list_colors[0]``` and <br>
# ```list_colors[1]```?
#
# 3. How do you concatenate two strings?
# 4. What does the error "not defined" mean?
# 5. What does the error "could not be broadcast" mean?
# 6. How do you compute the median of an array?

# %%
# Write your answers here as comments:

#1. lists can contain and mix any type of data, like str and float, while arrays are 
#   essentially lists but with only numerical data. Math operations can then be done on arrays, 
#   making them very useful.

#2. list_colors[0] will output "red" and list_colors[1] will output "yellow". 
#   this is because all lists begin at zero, where the first element is considered as list[0]

#3. two strings are concatenated with the + sign in between the strings, for example
"hello" + " " + "friend"

#4 "Not defined" means that python is trying to use a variable or element that has not been created 
#   or that does not exist. Such as calling dataset or list "colors" when you have not imported 
#   or created anything with this name

#5 The "could not be broadcast" error means that operations were attempted to be performed on 
#   arrays of different ("incompatible") sizes, and therefore cannot be done

#6 the median of an array can be use via the {np.mean} function.
# Out:
# 'hello friend'

# %% [markdown]
# ## Long Questions

# %% [markdown]
# <font size = "5">
#
# (a) Import the pandas, matplotlib, and numpy packages

# %%
# Write your own code

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <font size = "5">
#
# (b) Open the dataset "worldbank_wdi_2019.csv" <br>
# in the "data" folder
#
# <font size = "3">
#
# - Read it as a pandas object called "wdi"
# - Note: This is a subset of the World Development Indicators for 2019
# - Each observation represents a different country

# %%
# Write your own code

wdi = pd.read_csv("data/worldbank_wdi_2019.csv")

# %% [markdown]
# <font size = "5">
#
# (c) Browse the dataset and manually create <br>
# a list of variable names

# %%
# Write your own code

# Create a list, e.g. "variable_names = [ "name1", "name2", "name3" ]"
# Manually type the names of the variables
# If you're viewing the dataset from the VS-Code "Variables" tool, you'll
# see an extra column "index". Do not include this in your list.

print(wdi.columns)

wdi_variables = ["year", "country_name", "life_expectancy", "gdp_per_capita_usd"]
print(f"The variables in the wdi dataset are: {wdi_variables}")
# Out:
# Index(['year', 'country_name', 'life_expectancy', 'gdp_per_capita_usd'], dtype='object')
# The variables in the wdi dataset are: ['year', 'country_name', 'life_expectancy', 'gdp_per_capita_usd']

# %% [markdown]
# <font size = "5">
#
# (d) Compute descriptive statistics for the fourth <br>
# variable in the dataset
#
# <font size = "3">
#
# - One way to do this is:
#
# wdi["gdp_per_capita_usd"].describe()
#
# - Do something similar, but with the list you created above.
# - Substitute "gdp_per_capita_usd" with a command that <br>
# automatically extracts the fourth element in the list

# %%
# Write your own code

# Remember that the numbering in Python starts at zero
# For example:
# list_colors = ["red","green","yellow"]
# list_colors[2] will output "yellow"

element4 = wdi_variables[3] #4th element

wdi[element4].describe()
# Out:
# count       255.000000
# mean      17230.949757
# std       25792.183785
# min         216.972968
# 25%        2186.046581
# 50%        6837.717826
# 75%       19809.323135
# max      199377.481800
# Name: gdp_per_capita_usd, dtype: float64

# %% [markdown]
# <font size = "5">
#
# (e) Show a scatter plot that shows "gdp_per_capita_usd" <br>
# in the x-axis and "lifexpectancy" in the y-axis. Label the axes.

# %%
# Write your own code


plt.scatter(x = wdi["gdp_per_capita_usd"], y = wdi["life_expectancy"])
plt.title("GDP of country vs life expectancy")
plt.xlabel("GDP per Capita (USD)")
plt.ylabel("Life Expectancy (years)")
plt.show()

# %% [markdown]
# <font size = "5">
#
# (f) Generate "vec_x" from a chi-square <br>
# distribution with (df = 1, size = 1000)
#
# <font size = "3">
#
# - Plot a histogram of each variable, with axis labels, and title
# - Create a new variable "vec_y" by the formula <br>
# $ y = e^x + 2x + 5$
# - Plot "vec_x" against "vec_y" and label the axes

# %%
# Write your own code

vec_x = np.random.chisquare(df = 1, size = 1000)

plt.hist(vec_x)
plt.title("Distribution of vec_x")
plt.xlabel("Chi-Sq distribution vec_x")
plt.ylabel("frequency")
plt.show()

vec_y = np.exp(vec_x) + 2*vec_x + 5

plt.scatter(x = vec_x, y = vec_y)
plt.xlabel("vec_x")
plt.ylabel("vec_y")
plt.show()

# %% [markdown]
# <font size = "5">
#
# (g) Research online how to create an array with <br>
# ```size = 1000``` entries, with all entries equal to one.
#
# <font size = "3">
#
# - Create a new matrix, ```X_mat``` that appends a <br>
# vector with only ones and "vec_x" from question (f) to form <br>
# a matrix with two columns and 1000 rows
# - Compute $(X_{mat}'X_{mat})^{-1}$

# %%
# Write your own code
ones = np.ones(1000)

X_mat = np.column_stack((ones, vec_x))
print("visualizing the few few rows of the appended matrix")
print(X_mat[:5]) # visualize

#X'mat = transpose of X_mat
X_mat_T = np.matrix.transpose(X_mat)
# X'_mat X_mat dot product
X_dot = np.dot(X_mat, X_mat_T)
#inverse of dot product

X_inv = np.linalg.inv(X_dot)
print("\nThe computed inverse: \n")
print(X_inv)
# Out:
# visualizing the few few rows of the appended matrix
# [[1.         1.61936534]
#  [1.         2.78282323]
#  [1.         1.03939184]
#  [1.         0.26586659]
#  [1.         0.56746845]]
#
# The computed inverse:
#
# [[ 7.58129245e+14 -2.33885734e+15  4.89721399e+15 ... -6.45618850e+15
#    4.25216587e+15  4.01147536e+15]
#  [-1.67058385e+14  1.26811387e+15 -2.71294872e+15 ...  3.53224507e+15
#   -2.42966366e+15 -2.50141085e+15]
#  [-1.40405799e+14  2.14402501e+14 -6.02131172e+14 ...  8.07134836e+14
#   -4.98746142e+14 -3.40904381e+14]
#  ...
#  [-3.87247119e+13  2.49999415e+14 -5.52095531e+14 ...  6.62908121e+14
#   -4.60220200e+14 -4.16880883e+14]
#  [ 7.48844194e+13 -4.76557642e+14  9.58154105e+14 ... -1.24165266e+15
#    8.91563943e+14  8.73925313e+14]
#  [-3.47301334e+13  1.12824030e+14 -2.28405700e+14 ...  3.33916313e+14
#   -2.25679575e+14 -2.61659185e+14]]
