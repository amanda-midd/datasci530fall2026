# %% [markdown]
# # Lecture 2 Exercises

# %% [markdown]
# ## Short Questions
#
# <font size = "5">
#
# 1. How do you check whether an element is part of a list?
# 2. How do you reference a global variable in ```.query()```?

# %%
# Write your answers here as comments:

#1. To check whether an element is present in a list you use the "in" 
#   command, for example
list_a = ['a', 'b']
"a" in list_a

#2. to reference a global variable in a query, the "@" symbol 
#   is required in the logical expression
# Out:
# True

# %% [markdown]
# ## Long Questions

# %% [markdown]
# <font size = "5">
#
# Import the pandas and matplotlib packages

# %%
# Write your own code
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <font size = "5">
#
# (a) Checking a string condition
#
# <font size = "3">
#
# - Define a variable "fruit" with the value "apple"
# - Define a list
#
# list_fruits = ["banana","orange","apple"]
# - Write an expression to test whether "fruit" is contained in "list_fruits"
#
# Hint: Use the "in" command. The final output should be True/False.
#
# To get full points run all of the above commands

# %%
# Write your own code
fruit = 'apple'

list_fruits = ["banana","orange","apple"]
print(f'Is "{fruit}" in the list?  {fruit in list_fruits}')
# Out:
# Is "apple" in the list?  True

# %% [markdown]
# <font size = "5">
#
# (b) Classifying a variable
#
# <font size = "3">
#
# - Define a new variable "year" an assign the value "2008"
# - Write an if/else statement that does the following
#     - print("Year 2000 or earlier") if the year is less than or equal to  2000.
#     - print("Between 2001 and 2005") if the year is between 2001 and 2005.
#     - print("Year 2006 or later") if the year is after 2005.
#
# To get full points you must do all of the above instructions

# %%
# Write your own code
year = 2008

if year <= 2000:
    print('Year 2000 or earlier')
elif year >= 2001 | year <= 2005:
    print('Year between 2001 and 2005')
else:
    print('Year 2006 or later')
# Out:
# Year 2006 or later

# %% [markdown]
# <font size = "5">
#
# (c) Split a dataset into subsets
#
# <font size = "3">
#
# - Import the "features.csv" file as a pandas dataframe called "data"
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n = 1000$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" or "1" <br>
# $\qquad$ with equal probability
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code
data = pd.read_csv("data_raw/features.csv") 

list_status = [0,1]
list_prob = [0.5, 0.5]

n = len(data)

data["status"] = np.random.choice(list_status,
                                  size = n,
                                  p = list_prob)

data0 = data.query("status == 0")
print(f'Data0 \n {data0.head(5)}')
data1 = data.query("status == 1")
print(f'\nData1 \n {data1.head(5)}')
# Out:
# Data0
#      mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id  \
# 3  16.0          8           304        150    3433          12.0  A-1689813
# 5  15.0          8           429        198    4341          10.0  F-1689835
# 6  14.0          8           454        220    4354           9.0  C-1689846
# 7  14.0          8           440        215    4312           8.5  P-1689857
# 8  14.0          8           455        225    4425          10.0  P-1689868
#
#    status
# 3       0
# 5       0
# 6       0
# 7       0
# 8       0
#
# Data1
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle_id  \
# 0   18.0          8           307        130    3504          12.0  C-1689780
# 1   15.0          8           350        165    3693          11.5  B-1689791
# 2   18.0          8           318        150    3436          11.0  P-1689802
# 4   17.0          8           302        140    3449          10.5  F-1689824
# 10  15.0          8           383        170    3563          10.0  D-1689890
#
#     status
# 0        1
# 1        1
# 2        1
# 4        1
# 10       1

# %% [markdown]
# <font size = "5">
#
# For questions (d) through (f) mport the dataset <br>
#  "data_raw/fifa23_players_basic.csv"
#
# <font size = "3">
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code
fifa = pd.read_csv("data_raw/fifa23_players_basic.csv") 
display(fifa)
# Out:
#              Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0            L. Messi        Lionel Messi       91         91        54000000
# 1          K. Benzema       Karim Benzema       91         91        64000000
# 2      R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3        K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4           K. Mbappé       Kylian Mbappé       91         95       190500000
# ...               ...                 ...      ...        ...             ...
# 18534      D. Collins      Darren Collins       47         56          110000
# 18535    Yang Dejiang        Dejiang Yang       47         57           90000
# 18536       L. Mullan         Liam Mullan       47         67          130000
# 18537    D. McCallion    Daithí McCallion       47         61          100000
# 18538        N. Rabha         Nabin Rabha       47         50           60000
#
#       Positions Played Best Position          Nationality  \
# 0                   RW           CAM            Argentina
# 1                CF,ST            CF               France
# 2                   ST            ST               Poland
# 3               CM,CAM            CM              Belgium
# 4                ST,LW            ST               France
# ...                ...           ...                  ...
# 18534            ST,RM           CAM  Republic of Ireland
# 18535              CDM           CDM             China PR
# 18536               CM            RM     Northern Ireland
# 18537               CB            CB  Republic of Ireland
# 18538               LB            LB                India
#
#                                              Image Link  Age  ...  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1      https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2      https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3      https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4      https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                 ...  ...  ...
# 18534  https://cdn.sofifa.net/players/243/725/23_60.png   21  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
# 18538  https://cdn.sofifa.net/players/261/424/23_60.png   25  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 0                Left                 4            4
# 1               Right                 4            4
# 2               Right                 4            4
# 3               Right                 5            4
# 4               Right                 4            5
# ...               ...               ...          ...
# 18534           Right                 3            2
# 18535           Right                 3            2
# 18536           Right                 3            2
# 18537           Right                 3            2
# 18538            Left                 3            2
#
#        International Reputation National Team Name  \
# 0                             5          Argentina
# 1                             4             France
# 2                             5             Poland
# 3                             4            Belgium
# 4                             4             France
# ...                         ...                ...
# 18534                         1                  -
# 18535                         1                  -
# 18536                         1                  -
# 18537                         1                  -
# 18538                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 1      https://cdn.sofifa.net/flags/fr.png                      ST
# 2      https://cdn.sofifa.net/flags/pl.png                      ST
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# ...                                    ...                     ...
# 18534                                    -                       -
# 18535                                    -                       -
# 18536                                    -                       -
# 18537                                    -                       -
# 18538                                    -                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 0                              10                 Low                 Low
# 1                              19              Medium              Medium
# 2                               9                High              Medium
# 3                               7                High                High
# 4                              10                High                 Low
# ...                           ...                 ...                 ...
# 18534                           -              Medium              Medium
# 18535                           -              Medium              Medium
# 18536                           -                High              Medium
# 18537                           -              Medium              Medium
# 18538                           -              Medium              Medium
#
# [18539 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (d) Create a new dataset subsetting the <br>
# players whose age is less than 20

# %%
# Write your own code
fifa_under20 = fifa.query("Age < 20")

# checking if worked
display(fifa_under20)
print(f'Maximum age in subset: {np.max(fifa_under20['Age']) }')
print(f'Lowest age in subset: {np.min(fifa_under20['Age']) }')
# Out:
#             Known As             Full Name  Overall  Potential  \
# 82             Pedri  Pedro González López       85         93
# 124    J. Bellingham       Jude Bellingham       84         91
# 225         F. Wirtz         Florian Wirtz       82         91
# 302       J. Musiala         Jamal Musiala       81         90
# 527        Ansu Fati        Anssumane Fati       79         90
# ...              ...                   ...      ...        ...
# 18530         S. Bag             Sajal Bag       48         61
# 18533      Pi Ziyang             Ziyang Pi       47         60
# 18535   Yang Dejiang          Dejiang Yang       47         57
# 18536      L. Mullan           Liam Mullan       47         67
# 18537   D. McCallion      Daithí McCallion       47         61
#
#        Value(in Euro) Positions Played Best Position          Nationality  \
# 82          116000000               CM            CM                Spain
# 124          81500000            CM,LM            CM              England
# 225          66000000           CAM,CM           CAM              Germany
# 302          55500000        CM,LM,CAM           CAM              Germany
# 527          38000000               LW           CAM                Spain
# ...               ...              ...           ...                  ...
# 18530          110000            CM,RM            RM                India
# 18533          110000               CM           CAM             China PR
# 18535           90000              CDM           CDM             China PR
# 18536          130000               CM            RM     Northern Ireland
# 18537          100000               CB            CB  Republic of Ireland
#
#                                              Image Link  Age  ...  \
# 82     https://cdn.sofifa.net/players/251/854/23_60.png   19  ...
# 124    https://cdn.sofifa.net/players/252/371/23_60.png   19  ...
# 225    https://cdn.sofifa.net/players/256/630/23_60.png   19  ...
# 302    https://cdn.sofifa.net/players/256/790/23_60.png   19  ...
# 527    https://cdn.sofifa.net/players/253/004/23_60.png   19  ...
# ...                                                 ...  ...  ...
# 18530  https://cdn.sofifa.net/players/270/739/23_60.png   19  ...
# 18533  https://cdn.sofifa.net/players/269/066/23_60.png   19  ...
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png   17  ...
# 18536  https://cdn.sofifa.net/players/267/823/23_60.png   18  ...
# 18537  https://cdn.sofifa.net/players/267/824/23_60.png   17  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 82              Right                 4            4
# 124             Right                 4            4
# 225             Right                 4            4
# 302             Right                 4            4
# 527             Right                 4            4
# ...               ...               ...          ...
# 18530           Right                 4            2
# 18533           Right                 3            2
# 18535           Right                 3            2
# 18536           Right                 3            2
# 18537           Right                 3            2
#
#        International Reputation National Team Name  \
# 82                            2              Spain
# 124                           2            England
# 225                           2                  -
# 302                           1            Germany
# 527                           2                  -
# ...                         ...                ...
# 18530                         1                  -
# 18533                         1                  -
# 18535                         1                  -
# 18536                         1                  -
# 18537                         1                  -
#
#                       National Team Image Link  National Team Position  \
# 82         https://cdn.sofifa.net/flags/es.png                      CM
# 124    https://cdn.sofifa.net/flags/gb-eng.png                     SUB
# 225        https://cdn.sofifa.net/flags/de.png                       -
# 302        https://cdn.sofifa.net/flags/de.png                     SUB
# 527        https://cdn.sofifa.net/flags/es.png                       -
# ...                                        ...                     ...
# 18530                                        -                       -
# 18533                                        -                       -
# 18535                                        -                       -
# 18536                                        -                       -
# 18537                                        -                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 82                             10                High                High
# 124                            26                High                High
# 225                             -                High              Medium
# 302                            14              Medium              Medium
# 527                             -                High              Medium
# ...                           ...                 ...                 ...
# 18530                           -              Medium              Medium
# 18533                           -              Medium              Medium
# 18535                           -              Medium              Medium
# 18536                           -                High              Medium
# 18537                           -              Medium              Medium
#
# [1945 rows x 32 columns]
# maximum age in subset: 19
# lowest age in subset: 16

# %% [markdown]
# <font size = "5">
#
# (e) Use queries + global variables
#
# <font size = "3">
#
# - Compute the mean of the column "Value(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Value(in Euro)`    ``` inside .query()

# %%
# Write your own code
mean_Value = np.mean(fifa['Value(in Euro)'])
print(f'Average value(in Euro): {mean_Value}')

# subset
fifa_above_avg_Value = fifa.query(" `Value(in Euro)` > @mean_Value")
# check
display(fifa_above_avg_Value)
print(f'Lowest value(in Euro) in subset: {np.min(fifa_above_avg_Value['Value(in Euro)'])}')
# Out:
# average Value(in Euro): 2875461.4033658775
#             Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0           L. Messi        Lionel Messi       91         91        54000000
# 1         K. Benzema       Karim Benzema       91         91        64000000
# 2     R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3       K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4          K. Mbappé       Kylian Mbappé       91         95       190500000
# ...              ...                 ...      ...        ...             ...
# 7066       F. Rieder       Fabian Rieder       68         83         2900000
# 7071     J. Bakayoko      Johan Bakayoko       68         85         3100000
# 7090        M. Arezo        Matías Arezo       68         81         2900000
# 7096       Y. Kallon        Yayah Kallon       68         82         3000000
# 7168        M. Soulé        Matías Soulé       68         85         3100000
#
#      Positions Played Best Position   Nationality  \
# 0                  RW           CAM     Argentina
# 1               CF,ST            CF        France
# 2                  ST            ST        Poland
# 3              CM,CAM            CM       Belgium
# 4               ST,LW            ST        France
# ...               ...           ...           ...
# 7066           CAM,CM           CAM   Switzerland
# 7071               RW            LM       Belgium
# 7090           ST,CAM            ST       Uruguay
# 7096         RM,RW,CF            ST  Sierra Leone
# 7168               RW            LM     Argentina
#
#                                             Image Link  Age  ...  \
# 0     https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1     https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2     https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3     https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4     https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                ...  ...  ...
# 7066  https://cdn.sofifa.net/players/259/306/23_60.png   20  ...
# 7071  https://cdn.sofifa.net/players/265/450/23_60.png   19  ...
# 7090  https://cdn.sofifa.net/players/254/653/23_60.png   19  ...
# 7096  https://cdn.sofifa.net/players/262/333/23_60.png   21  ...
# 7168  https://cdn.sofifa.net/players/265/695/23_60.png   19  ...
#
#       Preferred Foot  Weak Foot Rating  Skill Moves  International Reputation  \
# 0               Left                 4            4                         5
# 1              Right                 4            4                         4
# 2              Right                 4            4                         5
# 3              Right                 5            4                         4
# 4              Right                 4            5                         4
# ...              ...               ...          ...                       ...
# 7066            Left                 3            2                         1
# 7071            Left                 3            3                         1
# 7090           Right                 3            4                         1
# 7096            Left                 2            3                         1
# 7168            Left                 4            4                         1
#
#      National Team Name             National Team Image Link  \
# 0             Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                France  https://cdn.sofifa.net/flags/fr.png
# 2                Poland  https://cdn.sofifa.net/flags/pl.png
# 3               Belgium  https://cdn.sofifa.net/flags/be.png
# 4                France  https://cdn.sofifa.net/flags/fr.png
# ...                 ...                                  ...
# 7066                  -  https://cdn.sofifa.net/flags/ch.png
# 7071                  -  https://cdn.sofifa.net/flags/be.png
# 7090                  -  https://cdn.sofifa.net/flags/uy.png
# 7096                  -                                    -
# 7168                  -  https://cdn.sofifa.net/flags/ar.png
#
#       National Team Position National Team Jersey Number Attacking Work Rate  \
# 0                         RW                          10                 Low
# 1                         ST                          19              Medium
# 2                         ST                           9                High
# 3                         RF                           7                High
# 4                         ST                          10                High
# ...                      ...                         ...                 ...
# 7066                       -                           -                High
# 7071                       -                           -                High
# 7090                       -                           -                High
# 7096                       -                           -                High
# 7168                       -                           -                High
#
#      Defensive Work Rate
# 0                    Low
# 1                 Medium
# 2                 Medium
# 3                   High
# 4                    Low
# ...                  ...
# 7066              Medium
# 7071              Medium
# 7090              Medium
# 7096                 Low
# 7168              Medium
#
# [3216 rows x 32 columns]
# lowest Value(in Euro) in subset: 2900000

# %% [markdown]
# <font size = "5">
#
# (f) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Age" column <br>
# from youngest to oldest
# - Get a subset with the 5 youngest players

# %%
# Write your own code

fifa_age_sort = fifa.sort_values(by = 'Age', ascending = True)
display(fifa_age_sort)

fifa_5youngest = fifa_age_sort.iloc[:5]
print(f'The 5 youngest players are {list(fifa_5youngest['Full Name'])}')
# Out:
#             Known As            Full Name  Overall  Potential  Value(in Euro)  \
# 17956     A. Dithmer      Andreas Dithmer       53         76          275000
# 18014      J. Ardila          José Ardila       53         73          250000
# 16084       S. Ngoma          Serge Ngoma       58         82          650000
# 11481      O. Vargas          Obed Vargas       64         81         1500000
# 17591  A. Madaliński      Alan Madaliński       54         68          210000
# ...              ...                  ...      ...        ...             ...
# 2423    Rubén Castro  Rubén Castro Martín       73         73               0
# 4499       G. Pegolo      Gianluca Pegolo       70         70          180000
# 3276      S. Torrico    Sebastián Torrico       72         72          250000
# 13548       S. Lukić         Stojan Lukić       62         62           45000
# 592        G. Buffon     Gianluigi Buffon       79         79         1900000
#
#       Positions Played Best Position             Nationality  \
# 17956               GK            GK                 Denmark
# 18014               CM           CAM               Venezuela
# 16084               RW            RM           United States
# 11481        CM,CDM,RM           CAM           United States
# 17591               GK            GK                  Poland
# ...                ...           ...                     ...
# 2423                ST            ST                   Spain
# 4499                GK            GK                   Italy
# 3276                GK            GK               Argentina
# 13548               GK            GK  Bosnia and Herzegovina
# 592                 GK            GK                   Italy
#
#                                              Image Link  Age  ...  \
# 17956  https://cdn.sofifa.net/players/269/573/23_60.png   16  ...
# 18014  https://cdn.sofifa.net/players/268/892/23_60.png   16  ...
# 16084  https://cdn.sofifa.net/players/267/796/23_60.png   16  ...
# 11481  https://cdn.sofifa.net/players/263/701/23_60.png   16  ...
# 17591  https://cdn.sofifa.net/players/270/590/23_60.png   16  ...
# ...                                                 ...  ...  ...
# 2423   https://cdn.sofifa.net/players/115/909/23_60.png   41  ...
# 4499   https://cdn.sofifa.net/players/106/795/23_60.png   41  ...
# 3276   https://cdn.sofifa.net/players/216/692/23_60.png   42  ...
# 13548  https://cdn.sofifa.net/players/213/483/23_60.png   42  ...
# 592    https://cdn.sofifa.net/players/001/179/23_60.png   44  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 17956           Right                 2            1
# 18014           Right                 3            2
# 16084           Right                 3            2
# 11481           Right                 3            3
# 17591           Right                 3            1
# ...               ...               ...          ...
# 2423            Right                 3            3
# 4499             Left                 2            1
# 3276            Right                 2            1
# 13548           Right                 2            1
# 592             Right                 2            1
#
#        International Reputation National Team Name  \
# 17956                         1                  -
# 18014                         1                  -
# 16084                         1                  -
# 11481                         1                  -
# 17591                         1                  -
# ...                         ...                ...
# 2423                          2                  -
# 4499                          1                  -
# 3276                          1                  -
# 13548                         1                  -
# 592                           4                  -
#
#                   National Team Image Link  National Team Position  \
# 17956  https://cdn.sofifa.net/flags/dk.png                       -
# 18014  https://cdn.sofifa.net/flags/ve.png                       -
# 16084  https://cdn.sofifa.net/flags/us.png                       -
# 11481  https://cdn.sofifa.net/flags/us.png                       -
# 17591  https://cdn.sofifa.net/flags/pl.png                       -
# ...                                    ...                     ...
# 2423   https://cdn.sofifa.net/flags/es.png                       -
# 4499   https://cdn.sofifa.net/flags/it.png                       -
# 3276   https://cdn.sofifa.net/flags/ar.png                       -
# 13548                                    -                       -
# 592    https://cdn.sofifa.net/flags/it.png                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 17956                           -              Medium              Medium
# 18014                           -              Medium              Medium
# 16084                           -                High              Medium
# 11481                           -                High              Medium
# 17591                           -              Medium              Medium
# ...                           ...                 ...                 ...
# 2423                            -              Medium                 Low
# 4499                            -              Medium              Medium
# 3276                            -              Medium              Medium
# 13548                           -              Medium              Medium
# 592                             -              Medium              Medium
#
# [18539 rows x 32 columns]
# the 5 youngest players are ['Andreas Dithmer', 'José Ardila', 'Serge Ngoma', 'Obed Vargas', 'Alan Madaliński']

# %% [markdown]
# <font size = "5">
# For questions (h)-(i), read "data_raw/wdi_2020.csv" <br>
# This is a dataset of countries from <br>
# the World Development Indicators

# %% [markdown]
# <font size = "5">
#
# (g) Extract sorted elements from a dataset
#
# <font size = "3">
#
# - Sort by "prop_urbanpopulation" in descending order
# - Subset the 5 countries with the highest urban population

# %%
# Write your own code
WDI = pd.read_csv('data_raw/wdi_2020.csv')

WDI_urbpop = WDI.sort_values(by = "prop_urbanpopulation", ascending = False)
display(WDI_urbpop)

WDI_urbpop5 = WDI_urbpop.iloc[:5]
print(f'Countries with the highest urban population: \n{list(WDI_urbpop5['countryname'])}')
# Out:
#      year yearcode               countryname countrycode  prop_urbanpopulation
# 212  2020   YR2020                 Singapore         SGP               100.000
# 147  2020   YR2020          Macao SAR, China         MAC               100.000
# 40   2020   YR2020            Cayman Islands         CYM               100.000
# 90   2020   YR2020                 Gibraltar         GIB               100.000
# 103  2020   YR2020      Hong Kong SAR, China         HKG               100.000
# ..    ...      ...                       ...         ...                   ...
# 34   2020   YR2020                   Burundi         BDI                13.708
# 191  2020   YR2020          Papua New Guinea         PNG                13.345
# 127  2020   YR2020                    Kosovo         XKX                   NaN
# 183  2020   YR2020            Not classified         INX                   NaN
# 227  2020   YR2020  St. Martin (French part)         MAF                   NaN
#
# [266 rows x 5 columns]
# Countries with the highest urban population:
# ['Singapore', 'Macao SAR, China', 'Cayman Islands', 'Gibraltar', 'Hong Kong SAR, China']

# %% [markdown]
# <font size = "5">
#
# (h) Subset elements with query
#
# <font size = "3">
#
# - Compute the median of "prop_urbanpopulation"
# - Use ".query()" to subset countries with <br>
#  "prop_urbanpopulation" above the median

# %%
# Write your own code
med_urbpop = WDI['prop_urbanpopulation'].median()
#np.median wasn't working, likely due to some missing values 

print(f'median urban population proportion: {med_urbpop}')

above_avg_urbpop = WDI.query('prop_urbanpopulation > @med_urbpop')
display(above_avg_urbpop)
# Out:
# median urban population proportion: 60.69872843
#      year yearcode            countryname countrycode  prop_urbanpopulation
# 3    2020   YR2020                Albania         ALB             62.112000
# 4    2020   YR2020                Algeria         DZA             73.733000
# 5    2020   YR2020         American Samoa         ASM             87.153000
# 6    2020   YR2020                Andorra         AND             87.916000
# 7    2020   YR2020                 Angola         AGO             66.825000
# ..    ...      ...                    ...         ...                   ...
# 254  2020   YR2020    Upper middle income         UMC             67.601442
# 255  2020   YR2020                Uruguay         URY             95.515000
# 258  2020   YR2020          Venezuela, RB         VEN             88.279000
# 260  2020   YR2020  Virgin Islands (U.S.)         VIR             95.939000
# 261  2020   YR2020     West Bank and Gaza         PSE             76.719000
#
# [131 rows x 5 columns]

# %% [markdown]
# <font size = "5">
#
# (i) Plot by category
#
# <font size = "3">
#
# - Read "data_raw/wdi_urban.csv"<br>
# This contains data from 1980 and 2020
#
# - Create a list with the unique values of "year"
# - Create a plot with a ...
#     - Histogram of "prop_urbanpopulation" <br>
#     for each year
#     - Set the histogram option ``` alpha = 0.5 ``` for transparency
#     - All the histograms should be overlapping
#     - Create a legend with the list of years
#     - Label the axes and the title
#
# What do we learn from the graph?
#
# HINT: See the example at the end of Lecture 10

# %%
# Write your own code

wdi_urban = pd.read_csv("data_raw/wdi_urban.csv")
display(wdi_urban.head(5))

years = pd.unique(wdi_urban['year'])

# histogram
for yr in years:
    df = wdi_urban.query('year == @yr')
    plt.hist(x = df["prop_urbanpopulation"], alpha = 0.5)

plt.title('Proportions of Urban Populations in 1980 vs 2020')
plt.xlabel('Urban population (%)')
plt.ylabel('Frequency')
plt.legend(labels = years, title = "Year")
plt.show()
# Out:
#    year yearcode     countryname countrycode  prop_urbanpopulation
# 0  1980   YR1980     Afghanistan         AFG                15.995
# 1  1980   YR1980         Albania         ALB                33.762
# 2  1980   YR1980         Algeria         DZA                43.542
# 3  1980   YR1980  American Samoa         ASM                74.330
# 4  1980   YR1980         Andorra         AND                92.064

# %%
# We see an increase in countries with high urban populations in 2020 from 1980. 
# This indicates a global pattern of urbanization.

# %% [markdown]
# # Review of last lecture

# %% [markdown]
# <font size = "5">
#
# (k) Composite operations on arrays
#
# <font size = "3">
#
# - Define $r = 0.04$
# - Define two arrays $A$ and $T$ using "np.array()", assigning the following values
#
# $ a = \begin{pmatrix} a_0 \\ a_1 \\ a_2 \end{pmatrix} =  \begin{pmatrix} 20 \\ 30 \\ 15 \end{pmatrix},
# \qquad  t = \begin{pmatrix} t_0 \\ t_1 \\ t_2 \end{pmatrix} = \begin{pmatrix} 0 \\ 1 \\ 2 \end{pmatrix} $
#
# - Use element-by-element vector operations to compute a new array $M$ of length 3:
#
# $ M = \begin{pmatrix} a_1 / (1+r)^{t_0}  \\ a_2 / (1+r)^{t_1} \\ a_3 / (1+r)^{t_2} \end{pmatrix} $
#
# - Compute the sum of the values of $M$ using "M.sum()"
#
# Note: I am using subscripts to denote the individual elements of $a$ and $t$.
# - In the code just enter the values of $a$ and $t$.
# - To get full points you must do all of the above tasks

# %%
# Write your own code

A = np.array([20, 30, 15])

T = np.array([0, 1, 2])

r = 0.04

M = A / (1 + r)**T
print(M)

M_sum = M.sum()
print(f'\nThe sum of the elements of M is {M_sum}')
# Out:
# [20.         28.84615385 13.8683432 ]
#
# the sum of the elements of M is 62.71449704142012
